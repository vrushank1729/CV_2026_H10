# %%
import numpy as np
import cv2

# %%
from google.colab.patches import cv2_imshow

img = cv2.imread('/content/image.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x853>

# %%
img.shape
# Out:
# (853, 1280, 3)

# %%
np_resize = np.resize(img, (182,275,3))
cv2_imshow(np_resize)
np_resize.shape
# Out:
# <PIL.Image.Image image mode=RGB size=275x182>
# (182, 275, 3)

# %%
cv_resize = cv2.resize(img, (275,182))
cv2_imshow(cv_resize)
cv_resize.shape
# Out:
# <PIL.Image.Image image mode=RGB size=275x182>
# (182, 275, 3)

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
croped_img = img[20:190, 230:400]
cv2_imshow(croped_img)
# Out:
# <PIL.Image.Image image mode=RGB size=170x170>

# %%
grey_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(grey_img)
# Out:
# <PIL.Image.Image image mode=L size=1280x853>
